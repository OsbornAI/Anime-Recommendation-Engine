# %% [markdown]
# # Scraped Data Analysis

# %% [markdown]
# ## This notebook is going to analyse the data scraped from the [MyAnimeList](https://myanimelist.net/) website.

# %% [markdown]
# #### Compile and load our data into a dataframe

# %%
import scraper
import os
 
csv_dir = os.path.join(os.getcwd(), 'anime-dataset', 'csv')

data_scraper = scraper.Scraper(csv_dir)

# data_scraper.buildCSV() # Scrape the data and store it in the CSV files

df = data_scraper.compileDF() # Compile our CSV's into a single dataframe containing the columns we want

# %%
df
# Out:
#                                          name_english  \
# 0                     Fullmetal Alchemist Brotherhood
# 1                                         Steins;Gate
# 2                                    Gintama Season 4
# 3                                     Hunter x Hunter
# 4                       Legend of the Galactic Heroes
# ..                                                ...
# 45                                                NaN
# 46                                  Cat Planet Cuties
# 47                                 Astarotte's Toy EX
# 48  The Idiot, the Tests, and the Summoned Creatur...
# 49   Please Save My Earth Movie From Alice to Rin-kun
#
#                    name_japanese show_type episodes  \
# 0     鋼の錬金術師 FULLMETAL ALCHEMIST        TV       64
# 1                    STEINS;GATE        TV       24
# 2                            銀魂°        TV       51
# 3       HUNTER×HUNTER（ハンター×ハンター）        TV      148
# 4                         銀河英雄伝説       OVA      110
# ..                           ...       ...      ...
# 45                        エイリアン9       OVA        4
# 46                      あそびにいくヨ!        TV       12
# 47               アスタロッテのおもちゃ! EX       OVA        1
# 48  バカとテストと召喚獣 問題 クリスマスについて答えなさい       ONA        1
# 49         ぼくの地球を守って～亜梨子から、輪くんへ～     Movie        1
#
#                                             producers  \
# 0   Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 1   Frontier Works, Media Factory, Movic, AT-X, Ka...
# 2                           TV Tokyo, Aniplex, Dentsu
# 3            VAP, Nippon Television Network, Shueisha
# 4                              Kitty Films, K-Factory
# ..                                                ...
# 45  Bandai Visual, Genco, MediaNet, AT-X, Nippon C...
# 46  AIC, Lantis, Media Factory, Pony Canyon, Rakuo...
# 47                                           add some
# 48                                           add some
# 49                   Victor Entertainment, Hakusensha
#
#                          licensors                studios  \
# 0   Funimation, Aniplex of America                  Bones
# 1                       Funimation              White Fox
# 2          Funimation, Crunchyroll  Bandai Namco Pictures
# 3                        Viz Media               Madhouse
# 4                 Sentai Filmworks     Artland, Magic Bus
# ..                             ...                    ...
# 45              Central Park Media              J.C.Staff
# 46                      Funimation              AIC Plus+
# 47                        add some               Diomedea
# 48                      Funimation           Silver Link.
# 49                        add some         Production I.G
#
#                                                genres episode_length rating  \
# 0   Action, Military, Adventure, Comedy, Drama, Ma...             24      R
# 1                                    Thriller, Sci-Fi             24  PG-13
# 2   Action, Comedy, Historical, Parody, Samurai, S...             24  PG-13
# 3    Action, Adventure, Fantasy, Shounen, Super Power             23  PG-13
# 4                      Military, Sci-Fi, Space, Drama             26      R
# ..                                                ...            ...    ...
# 45              Sci-Fi, Horror, Psychological, School             28      R
# 46              Comedy, Ecchi, Harem, Romance, Sci-Fi             24     R+
# 47    Comedy, Demons, Ecchi, Fantasy, Romance, Seinen             21     R+
# 48                                    Comedy, Romance              4  PG-13
# 49                     Drama, Romance, Sci-Fi, Shoujo            100  PG-13
#
#                                           description score_and_scorers  \
# 0   "In order for something to be obtained, someth...     9.22, 1238537
# 1   The self-proclaimed mad scientist Rintarou Oka...      9.12, 888306
# 2   Gintoki, Shinpachi, and Kagura return as the f...      9.11, 127501
# 3   Hunter x Hunter is set in a world where Hunter...      9.11, 834570
# 4   The 150-year-long stalemate between the two in...       9.10, 48184
# ..                                                ...               ...
# 45  Soon after entering middle school, Yuri Otani ...       6.67, 11353
# 46  Kio is just another boring, nice guy with a bo...       6.67, 72526
# 47  The OVA Astaroette no Omocha is a three part s...       6.67, 16046
# 48  The cast of Baka to Test all get together and ...       6.67, 18673
# 49  Please Save My Earth Movie: From Alice to Rin-...         6.67, 328
#
#    episode_length_bins episodes_bins
# 0                  <30            60
# 1                  <30           <30
# 2                  <30            60
# 3                  <30           150
# 4                  <30           120
# ..                 ...           ...
# 45                 <30           <30
# 46                 <30           <30
# 47                 <30           <30
# 48                 <30           <30
# 49                  90           <30
#
# [10776 rows x 14 columns]

# %% [markdown]
# ### Now let's look at all of the unique values from each column of the dataframe

# %%
unique_dic = {}
for column in df.columns[:-1]:
    unique_dic[column] = df[column].unique()

# %%
unique_dic['show_type']
# Out:
# array(['TV', 'OVA', 'Movie', 'ONA', 'Special', 'Music'], dtype=object)

# %%
unique_dic['episodes'] # Done
# Out:
# array([64, 24, 51, 148, 110, 10, 13, 22, 1, 12, 201, 7, 25, 14, 26, 75,
#        74, 4, 43, 47, 27, 11, 39, 37, 101, 99, 23, 15, 3, 38, 5, 2, 109,
#        44, 6, 16, 52, 48, 50, 72, 127, 9, 8, 331, 49, 31, 62, 130, 77,
#        170, NaT, 63, 19, 36, 20, 53, 29, 114, 60, 59, 54, 151, 214, 46,
#        58, 78, 40, 145, 21, 69, 108, 30, 35, 95, 164, 87, 28, 89, 45, 94,
#        61, 56, 34, 55, 83, 178, 119, 103, 32, 526, 91, 84, 140, 88, 100,
#        220, 73, 156, 80, 97, 104, 136, 143, 18, 167, 305, 42, 65, 96, 33,
#        113, 200, 726, 300, 17, 139, 1471, 366, 155, 163, 161, 102, 1006,
#        1565, 1428, 237, 373, 1818, 358, 175, 365, 120, 112, 195, 1787, 67,
#        263, 85, 124, 510, 475, 41, 142, 86, 312, 431, 115, 135, 70, 162,
#        132, 398, 125, 215, 147, 744, 68, 180, 283, 71, 154, 260, 199, 243,
#        150, 122, 79, 240, 105, 425, 1306, 773, 76, 224, 131, 276, 172,
#        128, 93, 92, 330, 137, 191, 203, 291, 193, 66, 192, 153, 500, 258,
#        296, 146, 694, 182, 117], dtype=object)

# %%
unique_dic['episode_length'] # Done
# Out:
# array([24, 23, 26, 25, 130, 106, 110, 22, 125, 83, 122, 105, 135, 30, 90,
#        119, 117, 162, 47, 28, 64, 108, 45, 114, 140, 95, 87, 88, 27, 161,
#        48, 18, 112, 42, 111, 5, 99, 89, 14, 93, 31, 60, 2, 3, 43, 6, 15,
#        1, 4, 76, 62, 29, 12, 75, 20, 13, 8, 10, 96, 9, 70, 118, 40, 54,
#        72, 21, 16, 33, 11, 56, 109, 101, 78, 7, 128, 39, 51, 50, 92, 66,
#        121, 132, 79, 38, 150, 85, 65, 44, 97, 74, 57, 100, 59, 46, 37, 91,
#        32, 126, 77, 120, 115, 94, 102, 52, 103, 55, 136, 17, 98, 86, 82,
#        80, 84, 69, 53, 19, 107, 71, 34, 67, 58, NaT, 63, 49, 35, 41, 73,
#        61, 36, 127, 68, 116, 104, 81, 113, 139, 131, 123, 148, 147, 167,
#        231, 134, 141, 156, 137, 124, 153, 152, 160, 163], dtype=object)

# %%
unique_dic['rating']
# Out:
# array(['R', 'PG-13', 'PG', 'R+', 'G', 'None'], dtype=object)
