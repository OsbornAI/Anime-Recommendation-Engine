# %% [markdown]
# # Scraped Data Analysis

# %% [markdown]
# ## This notebook is going to analyse the data scraped from the [MyAnimeList](https://myanimelist.net/) website.

# %% [markdown]
# #### Compile and load our data into a dataframe

# %%
import scraper
import os
 
csv_dir = os.path.join(os.getcwd(), 'anime-dataset', 'csv')

data_scraper = scraper.Scraper(csv_dir)

# data_scraper.buildCSV() # Scrape the data and store it in the CSV files

df = data_scraper.compileDF() # Compile our CSV's into a single dataframe containing the columns we want

# %%
df
# Out:
#                                          name_english  \
# 0                     Fullmetal Alchemist Brotherhood
# 1                                         Steins;Gate
# 2                                    Gintama Season 4
# 3                                     Hunter x Hunter
# 4                       Legend of the Galactic Heroes
# ..                                                ...
# 45                                                NaN
# 46                                  Cat Planet Cuties
# 47                                 Astarotte's Toy EX
# 48  The Idiot, the Tests, and the Summoned Creatur...
# 49   Please Save My Earth Movie From Alice to Rin-kun
#
#                    name_japanese show_type episodes  \
# 0     鋼の錬金術師 FULLMETAL ALCHEMIST        TV       64
# 1                    STEINS;GATE        TV       24
# 2                            銀魂°        TV       51
# 3       HUNTER×HUNTER（ハンター×ハンター）        TV      148
# 4                         銀河英雄伝説       OVA      110
# ..                           ...       ...      ...
# 45                        エイリアン9       OVA        4
# 46                      あそびにいくヨ!        TV       12
# 47               アスタロッテのおもちゃ! EX       OVA        1
# 48  バカとテストと召喚獣 問題 クリスマスについて答えなさい       ONA        1
# 49         ぼくの地球を守って～亜梨子から、輪くんへ～     Movie        1
#
#                                             producers  \
# 0   Aniplex, Square Enix, Mainichi Broadcasting Sy...
# 1   Frontier Works, Media Factory, Movic, AT-X, Ka...
# 2                           TV Tokyo, Aniplex, Dentsu
# 3            VAP, Nippon Television Network, Shueisha
# 4                              Kitty Films, K-Factory
# ..                                                ...
# 45  Bandai Visual, Genco, MediaNet, AT-X, Nippon C...
# 46  AIC, Lantis, Media Factory, Pony Canyon, Rakuo...
# 47                                           add some
# 48                                           add some
# 49                   Victor Entertainment, Hakusensha
#
#                          licensors                studios  \
# 0   Funimation, Aniplex of America                  Bones
# 1                       Funimation              White Fox
# 2          Funimation, Crunchyroll  Bandai Namco Pictures
# 3                        Viz Media               Madhouse
# 4                 Sentai Filmworks     Artland, Magic Bus
# ..                             ...                    ...
# 45              Central Park Media              J.C.Staff
# 46                      Funimation              AIC Plus+
# 47                        add some               Diomedea
# 48                      Funimation           Silver Link.
# 49                        add some         Production I.G
#
#                                                genres episode_length rating  \
# 0   Action, Military, Adventure, Comedy, Drama, Ma...             24      R
# 1                                    Thriller, Sci-Fi             24  PG-13
# 2   Action, Comedy, Historical, Parody, Samurai, S...             24  PG-13
# 3    Action, Adventure, Fantasy, Shounen, Super Power             23  PG-13
# 4                      Military, Sci-Fi, Space, Drama             26      R
# ..                                                ...            ...    ...
# 45              Sci-Fi, Horror, Psychological, School             28      R
# 46              Comedy, Ecchi, Harem, Romance, Sci-Fi             24     R+
# 47    Comedy, Demons, Ecchi, Fantasy, Romance, Seinen             21     R+
# 48                                    Comedy, Romance              4  PG-13
# 49                     Drama, Romance, Sci-Fi, Shoujo            100  PG-13
#
#                                           description episode_length_bins  \
# 0   "In order for something to be obtained, someth...                 <30
# 1   The self-proclaimed mad scientist Rintarou Oka...                 <30
# 2   Gintoki, Shinpachi, and Kagura return as the f...                 <30
# 3   Hunter x Hunter is set in a world where Hunter...                 <30
# 4   The 150-year-long stalemate between the two in...                 <30
# ..                                                ...                 ...
# 45  Soon after entering middle school, Yuri Otani ...                 <30
# 46  Kio is just another boring, nice guy with a bo...                 <30
# 47  The OVA Astaroette no Omocha is a three part s...                 <30
# 48  The cast of Baka to Test all get together and ...                 <30
# 49  Please Save My Earth Movie: From Alice to Rin-...                  90
#
#    episodes_bins score  scorers weighted_score
# 0             60  9.22  1238537       0.921518
# 1            <30  9.12   888306       0.911399
# 2             60  9.11   127501       0.909405
# 3            150  9.11   834570       0.910377
# 4            120   9.1    48184       0.907393
# ..           ...   ...      ...            ...
# 45           <30  6.67    11353       0.658154
# 46           <30  6.67    72526         0.6635
# 47           <30  6.67    16046       0.659559
# 48           <30  6.67    18673       0.660102
# 49           <30  6.67      328       0.614955
#
# [15000 rows x 16 columns]

# %%
labels_df = df.sort_values(by='weighted_score', ascending=False)
for i, anime in enumerate(list(labels_df['name_english'])[:100]):
    print(i+1, anime)
# Out:
# 0 Fullmetal Alchemist Brotherhood
# 1 Steins;Gate
# 2 Hunter x Hunter
# 3 Gintama Season 4
# 4 Legend of the Galactic Heroes
# 5 Gintama Season 2
# 6 Attack on Titan Season 3 Part 2
# 7 Gintama Enchousen
# 8 A Silent Voice
# 9 March Comes In Like A Lion 2nd Season
# 10 Your Name.
# 11 Gintama Season 5
# 12 Gintama
# 13 Clannad ~After Story~
# 14 nan
# 15 Owarimonogatari Second Season
# 16 Code Geass Lelouch of the Rebellion R2
# 17 Haikyu!! 3rd Season
# 18 Mob Psycho 100 II
# 19 Spirited Away
# 20 Gintama. Silver Soul Arc - Second Half War
# 21 nan
# 22 Cowboy Bebop
# 23 Kaguya-sama Love is War Season 2
# 24 Gintama. Silver Soul Arc
# 25 Monogatari Series Second Season
# 26 Your Lie in April
# 27 Haikyu!! 2nd Season
